# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
aggregate = pd.read_csv('./GeneratedDatasets/NCAA-Aggregate.csv')
differential = pd.read_csv('./GeneratedDatasets/NCAA-Differential.csv')
aggdiff = pd.read_csv('./GeneratedDatasets/NCAA-AggDiff.csv')
targagg = pd.read_csv('./GeneratedDatasets/2018Target-Aggregate.csv')
targdiff = pd.read_csv('./GeneratedDatasets/2018Target-Differential.csv')
targagdf = pd.read_csv('./GeneratedDatasets/2018Target-AggDiff.csv')

# %%
X_a = aggregate.drop(['ID', 'FavoriteID', 'UnderdogID', 'ExpectedWin'], axis=1)
y_a = aggregate['ExpectedWin']

# %%
X_d = differential.drop(['ID', 'FavoriteID', 'UnderdogID', 'ExpectedWin'], axis=1)
y_d = differential['ExpectedWin']

# %%
X_ad = aggdiff.drop(['ID', 'FavoriteID', 'UnderdogID', 'ExpectedWin'], axis=1)
y_ad = aggdiff['ExpectedWin']

# %%
Xa_train, Xa_test, ya_train, ya_test = train_test_split(X_a, y_a, random_state=2018, stratify=y_a)

# %%
Xd_train, Xd_test, yd_train, yd_test = train_test_split(X_d, y_d, random_state=317, stratify=y_d)

# %%
Xad_train, Xad_test, yad_train, yad_test = train_test_split(X_ad, y_ad, random_state=442, stratify = y_ad)

# %%
rf = RandomForestClassifier(random_state=1234)
rf_params = {'n_estimators': [int(n) for n in np.linspace(20, 50, 4)],
            'max_depth': [None, 2, 4, 6, 8],
            'max_features': ['auto', 'log2', 'sqrt'],
            'criterion': ['gini', 'entropy']}
gs_rfa = GridSearchCV(rf, rf_params)
gs_rfa.fit(Xa_train, ya_train)
print(gs_rfa.best_score_)
gs_rfa.best_params_
# Out:
# 0.7224489795918367
# {'criterion': 'entropy',
#  'max_depth': 8,
#  'max_features': 'log2',
#  'n_estimators': 50}

# %%
gs_rfa.score(Xa_test, ya_test)
# Out:
# 0.6910569105691057

# %%
rf = RandomForestClassifier(random_state=456)
rf_params = {'n_estimators': [int(n) for n in np.linspace(20, 50, 4)],
            'max_depth': [None, 2, 4, 6, 8],
            'max_features': ['auto', 'log2', 'sqrt'],
            'criterion': ['gini', 'entropy']}
gs_rfd = GridSearchCV(rf, rf_params)
gs_rfd.fit(Xd_train, yd_train)
print(gs_rfd.best_score_)
gs_rfd.best_params_
# Out:
# 0.708843537414966
# {'criterion': 'gini',
#  'max_depth': 4,
#  'max_features': 'auto',
#  'n_estimators': 50}

# %%
gs_rfd.score(Xd_test, yd_test)
# Out:
# 0.7154471544715447

# %%
rf = RandomForestClassifier(random_state=789)
rf_params = {'n_estimators': [int(n) for n in np.linspace(20, 50, 4)],
            'max_depth': [None, 2, 4, 6, 8],
            'max_features': ['auto', 'log2', 'sqrt'],
            'criterion': ['gini', 'entropy']}
gs_rfad = GridSearchCV(rf, rf_params)
gs_rfad.fit(Xad_train, yad_train)
print(gs_rfad.best_score_)
gs_rfad.best_params_
# Out:
# 0.7251700680272108
# {'criterion': 'gini',
#  'max_depth': 8,
#  'max_features': 'log2',
#  'n_estimators': 40}

# %%
gs_rfad.score(Xad_test, yad_test)
# Out:
# 0.7073170731707317

# %%
y_a.mean()
# Out:
# 0.7064220183486238

# %%
gs_rfd.predict_proba(targdiff.drop('ID', axis=1))
# Out:
# array([[0.49894016, 0.50105984],
#        [0.4255358 , 0.5744642 ],
#        [0.49918283, 0.50081717],
#        ...,
#        [0.17129167, 0.82870833],
#        [0.47104572, 0.52895428],
#        [0.4545172 , 0.5454828 ]])

# %%
predictions = pd.DataFrame(columns=['ID', 'Pred'])
for n in range(len(gs_rfd.predict_proba(targdiff.drop('ID', axis=1)))):
    predictions.loc[n, 'ID'] = targdiff.loc[n, 'ID']
    predictions.loc[n, 'Pred'] = gs_rfd.predict_proba(targdiff.drop('ID', axis=1))[n][1]

# %%
predictions.head(10)
# Out:
#                ID      Pred
# 0  2018_1104_1112   0.50106
# 1  2018_1104_1113  0.574464
# 2  2018_1104_1116  0.500817
# 3  2018_1104_1120   0.50943
# 4  2018_1104_1137  0.656441
# 5  2018_1104_1138  0.558563
# 6  2018_1104_1139  0.549669
# 7  2018_1104_1153  0.420564
# 8  2018_1104_1155  0.522485
# 9  2018_1104_1158   0.69141

# %%
targdiff.tail()
# Out:
#                   ID  WinsDiff  LossesDiff  PercentageDiff  MeanRankDiff  \
# 2273  2018_1452_1460         1           1          -0.013      -113.475
# 2274  2018_1452_1462        -4           5          -0.142         6.492
# 2275  2018_1455_1460         2          -2           0.062      -113.312
# 2276  2018_1455_1462        -3           2          -0.067         6.656
# 2277  2018_1460_1462        -5           4          -0.129       119.967
#
#       AbsMeanRankDiff  SeedDiff  coach_expDiff  made_tournamentDiff  \
# 2273             -112        -9             20                   20
# 2274                8         4             24                   16
# 2275             -111       -10              7                   10
# 2276                9         3             11                    6
# 2277              120        13              4                   -4
#
#       first_roundDiff           ...            AgstOppOffAvgOppFGA3Diff  \
# 2273               20           ...                              -1.662
# 2274               17           ...                              -5.452
# 2275                9           ...                               1.167
# 2276                6           ...                              -2.623
# 2277               -3           ...                              -3.790
#
#       AgstOppOffAvgOppFTMDiff  AgstOppOffAvgOppFTADiff  \
# 2273                    4.249                    6.262
# 2274                    5.632                    8.578
# 2275                    1.444                    1.686
# 2276                    2.827                    4.002
# 2277                    1.383                    2.316
#
#       AgstOppOffAvgOppORDiff  AgstOppOffAvgOppDRDiff  AgstOppOffAvgOppAstDiff  \
# 2273                   1.103                  -0.945                   -0.137
# 2274                   1.700                   2.004                   -1.696
# 2275                  -1.387                  -2.565                   -0.759
# 2276                  -0.790                   0.384                   -2.318
# 2277                   0.597                   2.949                   -1.559
#
#       AgstOppOffAvgOppTODiff  AgstOppOffAvgOppStlDiff  \
# 2273                   2.107                   -0.467
# 2274                   4.962                   -1.170
# 2275                  -2.698                    0.209
# 2276                   0.157                   -0.494
# 2277                   2.855                   -0.703
#
#       AgstOppOffAvgOppBlkDiff  AgstOppOffAvgOppPFDiff
# 2273                    0.736                  -0.759
# 2274                    0.190                  -1.907
# 2275                    0.598                   0.422
# 2276                    0.052                  -0.726
# 2277                   -0.546                  -1.148
#
# [5 rows x 72 columns]

# %%
teams = pd.read_csv('./GeneratedDatasets/generated2018.csv')
teams[teams['TeamID'] == 1455]['TeamName']
# Out:
# 65    Wichita St
# Name: TeamName, dtype: object

# %%
teams[teams['TeamID'] == 1460]['TeamName']
# Out:
# 66    Wright St
# Name: TeamName, dtype: object

# %%
teams['TeamName']
# Out:
# 0            Alabama
# 1            Arizona
# 2         Arizona St
# 3           Arkansas
# 4             Auburn
# 5           Bucknell
# 6            Buffalo
# 7             Butler
# 8         Cincinnati
# 9            Clemson
# 10    Col Charleston
# 11         Creighton
# 12      CS Fullerton
# 13          Davidson
# 14              Duke
# 15           Florida
# 16        Florida St
# 17        Georgia St
# 18           Gonzaga
# 19           Houston
# 20              Iona
# 21            Kansas
# 22         Kansas St
# 23          Kentucky
# 24          Lipscomb
# 25       Long Island
# 26    Loyola-Chicago
# 27          Marshall
# 28          Miami FL
# 29          Michigan
#            ...
# 38    North Carolina
# 39           Ohio St
# 40          Oklahoma
# 41              Penn
# 42        Providence
# 43            Purdue
# 44           Radford
# 45      Rhode Island
# 46       S Dakota St
# 47      San Diego St
# 48        Seton Hall
# 49         SF Austin
# 50    St Bonaventure
# 51          Syracuse
# 52               TCU
# 53         Tennessee
# 54             Texas
# 55         Texas A&M
# 56        Texas Tech
# 57       TX Southern
# 58              UCLA
# 59              UMBC
# 60    UNC Greensboro
# 61         Villanova
# 62          Virginia
# 63     Virginia Tech
# 64     West Virginia
# 65        Wichita St
# 66         Wright St
# 67            Xavier
# Name: TeamName, Length: 68, dtype: object

# %%
teams[teams['TeamName'] == 'Long Island']
# Out:
#     TeamID     TeamName  Wins  Losses  Percentage  MeanRank  AbsMeanRank  \
# 25    1254  Long Island    17      16       0.515  256.9344          257
#
#     Seed  coach_exp  made_tournament         ...          \
# 25    16         10                1         ...
#
#     AgstOppOffAvgOppFGA3  AgstOppOffAvgOppFTM  AgstOppOffAvgOppFTA  \
# 25                -1.101                1.072                1.868
#
#     AgstOppOffAvgOppOR  AgstOppOffAvgOppDR  AgstOppOffAvgOppAst  \
# 25                1.65               0.697                0.279
#
#     AgstOppOffAvgOppTO  AgstOppOffAvgOppStl  AgstOppOffAvgOppBlk  \
# 25              -1.408                0.121               -0.284
#
#     AgstOppOffAvgOppPF
# 25               1.649
#
# [1 rows x 73 columns]

# %%
teams[teams['TeamName'] == 'Radford']
# Out:
#     TeamID TeamName  Wins  Losses  Percentage  MeanRank  AbsMeanRank  Seed  \
# 44    1347  Radford    20      12       0.625  166.4262          166    16
#
#     coach_exp  made_tournament         ...          AgstOppOffAvgOppFGA3  \
# 44          7                0         ...                        -1.573
#
#     AgstOppOffAvgOppFTM  AgstOppOffAvgOppFTA  AgstOppOffAvgOppOR  \
# 44               -0.781               -1.905               0.406
#
#     AgstOppOffAvgOppDR  AgstOppOffAvgOppAst  AgstOppOffAvgOppTO  \
# 44              -2.043               -1.615              -0.051
#
#     AgstOppOffAvgOppStl  AgstOppOffAvgOppBlk  AgstOppOffAvgOppPF
# 44               -0.691                0.241               -0.93
#
# [1 rows x 73 columns]

# %%
teams[teams['TeamName'] == 'St Bonaventure']
# Out:
#     TeamID        TeamName  Wins  Losses  Percentage  MeanRank  AbsMeanRank  \
# 50    1382  St Bonaventure    25       7       0.781   51.4918           51
#
#     Seed  coach_exp  made_tournament         ...          \
# 50    11         17                1         ...
#
#     AgstOppOffAvgOppFGA3  AgstOppOffAvgOppFTM  AgstOppOffAvgOppFTA  \
# 50                 1.867                2.701                3.697
#
#     AgstOppOffAvgOppOR  AgstOppOffAvgOppDR  AgstOppOffAvgOppAst  \
# 50               0.829              -0.682               -0.622
#
#     AgstOppOffAvgOppTO  AgstOppOffAvgOppStl  AgstOppOffAvgOppBlk  \
# 50               2.384                -0.79                0.652
#
#     AgstOppOffAvgOppPF
# 50               2.398
#
# [1 rows x 73 columns]

# %%
teams[teams['TeamName'] == 'UCLA']
# Out:
#     TeamID TeamName  Wins  Losses  Percentage  MeanRank  AbsMeanRank  Seed  \
# 58    1417     UCLA    21      11       0.656    46.459           47    11
#
#     coach_exp  made_tournament         ...          AgstOppOffAvgOppFGA3  \
# 58         23               10         ...                         4.696
#
#     AgstOppOffAvgOppFTM  AgstOppOffAvgOppFTA  AgstOppOffAvgOppOR  \
# 58               -1.433               -1.493               0.324
#
#     AgstOppOffAvgOppDR  AgstOppOffAvgOppAst  AgstOppOffAvgOppTO  \
# 58               0.448                0.082              -2.119
#
#     AgstOppOffAvgOppStl  AgstOppOffAvgOppBlk  AgstOppOffAvgOppPF
# 58               -0.028               -1.336               0.994
#
# [1 rows x 73 columns]

# %%
predictions[predictions['ID'] == '2018_1254_1347']
# Out:
#                   ID      Pred
# 1393  2018_1254_1347  0.487431

# %%
predictions[predictions['ID'] == '2018_1382_1417']
# Out:
#                   ID      Pred
# 2132  2018_1382_1417  0.604193

# %%
predictions.to_csv('predictions-rfd.csv', index=False)

# %%
predictions_a = pd.DataFrame(columns=['ID', 'Pred'])
for n in range(len(gs_rfa.predict_proba(targagg.drop('ID', axis=1)))):
    predictions_a.loc[n, 'ID'] = targagg.loc[n, 'ID']
    predictions_a.loc[n, 'Pred'] = gs_rfa.predict_proba(targagg.drop('ID', axis=1))[n][1]

# %%
predictions_a.head(10)
# Out:
#                ID      Pred
# 0  2018_1104_1112  0.384016
# 1  2018_1104_1113   0.64479
# 2  2018_1104_1116  0.534664
# 3  2018_1104_1120  0.442356
# 4  2018_1104_1137  0.617004
# 5  2018_1104_1138  0.692896
# 6  2018_1104_1139  0.488097
# 7  2018_1104_1153  0.436746
# 8  2018_1104_1155  0.437414
# 9  2018_1104_1158  0.511926

# %%
predictions_a.to_csv('predictions-rfa.csv', index=False)

# %%
predictions_ad = pd.DataFrame(columns=['ID', 'Pred'])
for n in range(len(gs_rfad.predict_proba(targagdf.drop('ID', axis=1)))):
    predictions_ad.loc[n, 'ID'] = targagdf.loc[n, 'ID']
    predictions_ad.loc[n, 'Pred'] = gs_rfad.predict_proba(targagdf.drop('ID', axis=1))[n][1]

# %%
predictions_ad.head(10)
# Out:
#                ID      Pred
# 0  2018_1104_1112  0.449973
# 1  2018_1104_1113  0.654197
# 2  2018_1104_1116  0.625729
# 3  2018_1104_1120   0.65478
# 4  2018_1104_1137  0.848554
# 5  2018_1104_1138  0.704483
# 6  2018_1104_1139  0.565392
# 7  2018_1104_1153  0.409309
# 8  2018_1104_1155  0.517792
# 9  2018_1104_1158   0.72617

# %%
predictions_ad.to_csv('predictions-rfad.csv', index=False)

# %%
predictions_a[predictions_a['ID'] == '2018_1254_1347']
# Out:
#                   ID      Pred
# 1393  2018_1254_1347  0.591774

# %%
predictions_a[predictions_a['ID'] == '2018_1382_1417']
# Out:
#                   ID      Pred
# 2132  2018_1382_1417  0.761471

# %%
predictions_ad[predictions_ad['ID'] == '2018_1254_1347']
# Out:
#                   ID      Pred
# 1393  2018_1254_1347  0.525648

# %%
predictions_ad[predictions_ad['ID'] == '2018_1382_1417']
# Out:
#                   ID      Pred
# 2132  2018_1382_1417  0.554241

# %%
pred1 = pd.read_csv('predictions-rfd.csv')
pred2 = pd.read_csv('predictions-rfa.csv')
pred3 = pd.read_csv('predictions-rfad.csv')

# %%
df = pd.DataFrame(columns =['ID', 'Pred'])
for p in range(len(pred1)):
    df.loc[p, 'ID'] = pred1.loc[p, 'ID']
    df.loc[p, 'Pred'] = (pred1.loc[p, 'Pred'] + pred2.loc[p, 'Pred'] + pred3.loc[p, 'Pred']) / 3
df
# Out:
#                   ID      Pred
# 0     2018_1104_1112  0.445016
# 1     2018_1104_1113  0.624484
# 2     2018_1104_1116  0.553737
# 3     2018_1104_1120  0.535522
# 4     2018_1104_1137  0.707333
# 5     2018_1104_1138  0.651981
# 6     2018_1104_1139  0.534386
# 7     2018_1104_1153  0.422206
# 8     2018_1104_1155  0.492564
# 9     2018_1104_1158  0.643169
# 10    2018_1104_1166  0.617145
# 11    2018_1104_1168  0.779688
# 12    2018_1104_1172  0.542493
# 13    2018_1104_1181  0.403543
# 14    2018_1104_1196  0.487513
# 15    2018_1104_1199  0.571331
# 16    2018_1104_1209  0.679525
# 17    2018_1104_1211  0.432376
# 18    2018_1104_1222  0.450954
# 19    2018_1104_1233  0.775962
# 20    2018_1104_1242  0.474279
# 21    2018_1104_1243  0.466378
# 22    2018_1104_1246  0.456516
# 23    2018_1104_1252  0.751465
# 24    2018_1104_1254  0.826797
# 25    2018_1104_1260  0.521868
# 26    2018_1104_1267  0.753414
# 27    2018_1104_1274   0.47139
# 28    2018_1104_1276  0.484171
# 29    2018_1104_1277   0.47001
# ...              ...       ...
# 2248  2018_1420_1460    0.5515
# 2249  2018_1420_1462  0.505263
# 2250  2018_1422_1437   0.53739
# 2251  2018_1422_1438  0.538683
# 2252  2018_1422_1439  0.633661
# 2253  2018_1422_1452  0.533737
# 2254  2018_1422_1455  0.575526
# 2255  2018_1422_1460  0.651813
# 2256  2018_1422_1462  0.600926
# 2257  2018_1437_1438  0.638026
# 2258  2018_1437_1439  0.847833
# 2259  2018_1437_1452  0.702981
# 2260  2018_1437_1455   0.64869
# 2261  2018_1437_1460  0.839167
# 2262  2018_1437_1462  0.668997
# 2263  2018_1438_1439  0.755194
# 2264  2018_1438_1452  0.612956
# 2265  2018_1438_1455  0.696386
# 2266  2018_1438_1460  0.820817
# 2267  2018_1438_1462  0.670599
# 2268  2018_1439_1452   0.56998
# 2269  2018_1439_1455  0.494591
# 2270  2018_1439_1460  0.725148
# 2271  2018_1439_1462  0.503535
# 2272  2018_1452_1455  0.562924
# 2273  2018_1452_1460  0.800667
# 2274  2018_1452_1462   0.58681
# 2275  2018_1455_1460  0.805743
# 2276  2018_1455_1462  0.586354
# 2277  2018_1460_1462  0.524303
#
# [2278 rows x 2 columns]

# %%
df.to_csv('predictions-rfens.csv', index=False)

# %%
rf = RandomForestClassifier(n_estimators=50, max_depth=4, random_state=456)
rf.fit(Xd_train, yd_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=4, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=1,
#             oob_score=False, random_state=456, verbose=0, warm_start=False)

# %%
rf.feature_importances_
# Out:
# array([0.03705568, 0.01670858, 0.03297958, 0.09481977, 0.08783773,
#        0.0578696 , 0.01046326, 0.00491572, 0.00628386, 0.01156073,
#        0.01196237, 0.01609396, 0.00616816, 0.00561126, 0.00035908,
#        0.01351707, 0.03971462, 0.0036145 , 0.00561317, 0.00305416,
#        0.00249374, 0.00339897, 0.00956999, 0.0130863 , 0.01879811,
#        0.01749487, 0.0120138 , 0.01226549, 0.0159566 , 0.02074517,
#        0.0072751 , 0.00714237, 0.00828024, 0.01122802, 0.00193703,
#        0.00811965, 0.016241  , 0.01079158, 0.0201164 , 0.01142992,
#        0.00354408, 0.00067235, 0.00366281, 0.01512926, 0.02179671,
#        0.00853862, 0.00850946, 0.00395959, 0.00270588, 0.00945157,
#        0.01259426, 0.00260412, 0.00665082, 0.00472458, 0.01013255,
#        0.01340319, 0.00187739, 0.02481193, 0.02020685, 0.00744892,
#        0.01047426, 0.00581577, 0.00745573, 0.0099296 , 0.00474564,
#        0.0124173 , 0.01785171, 0.02594311, 0.00451797, 0.01499682,
#        0.00883994])

# %%
targdiff
# Out:
#                   ID  WinsDiff  LossesDiff  PercentageDiff  MeanRankDiff  \
# 0     2018_1104_1112        -8           8          -0.235        31.590
# 1     2018_1104_1113        -1           4          -0.086        12.705
# 2     2018_1104_1116        -4           4          -0.117        24.492
# 3     2018_1104_1120        -6           8          -0.222        42.738
# 4     2018_1104_1137        -6           6          -0.176       -43.902
# 5     2018_1104_1138        -6           7          -0.199       -17.492
# 6     2018_1104_1139        -1           2          -0.047        22.935
# 7     2018_1104_1153       -11          11          -0.323        48.885
# 8     2018_1104_1155        -4           6          -0.160        35.295
# 9     2018_1104_1158        -5           8          -0.215       -51.590
# 10    2018_1104_1166        -1           4          -0.086        25.574
# 11    2018_1104_1168         1           4          -0.062      -112.672
# 12    2018_1104_1172        -2           4          -0.097       -15.574
# 13    2018_1104_1181        -7           8          -0.229        51.213
# 14    2018_1104_1196        -1           3          -0.066        31.984
# 15    2018_1104_1199        -1           4          -0.086        16.869
# 16    2018_1104_1209        -3           5          -0.129       -70.836
# 17    2018_1104_1211       -11          11          -0.323        42.475
# 18    2018_1104_1222        -7           8          -0.229        32.361
# 19    2018_1104_1233        -1           2          -0.047       -84.754
# 20    2018_1104_1242        -8           8          -0.235        46.246
# 21    2018_1104_1243        -3           4          -0.108        16.246
# 22    2018_1104_1246        -5           5          -0.147        33.525
# 23    2018_1104_1252        -1           6          -0.131       -90.246
# 24    2018_1104_1254         2          -1           0.044      -202.098
# 25    2018_1104_1260        -8          10          -0.285         9.820
# 26    2018_1104_1267        -4           5          -0.138       -56.557
# 27    2018_1104_1274        -3           6          -0.151        23.672
# 28    2018_1104_1276        -8           8          -0.235        43.967
# 29    2018_1104_1277       -10          11          -0.320        48.656
# ...              ...       ...         ...             ...           ...
# 2248  2018_1420_1460        -2           1          -0.042        51.295
# 2249  2018_1420_1462        -7           5          -0.171       171.262
# 2250  2018_1422_1437        -6           3          -0.108        81.770
# 2251  2018_1422_1438        -7           5          -0.165        81.918
# 2252  2018_1422_1439         3          -4           0.118        50.262
# 2253  2018_1422_1452         0          -3           0.068        68.951
# 2254  2018_1422_1455        -1           0          -0.007        68.787
# 2255  2018_1422_1460         1          -2           0.055       -44.525
# 2256  2018_1422_1462        -4           2          -0.074        75.443
# 2257  2018_1437_1438        -1           2          -0.057         0.147
# 2258  2018_1437_1439         9          -7           0.226       -31.508
# 2259  2018_1437_1452         6          -6           0.176       -12.820
# 2260  2018_1437_1455         5          -3           0.101       -12.984
# 2261  2018_1437_1460         7          -5           0.163      -126.295
# 2262  2018_1437_1462         2          -1           0.034        -6.328
# 2263  2018_1438_1439        10          -9           0.283       -31.656
# 2264  2018_1438_1452         7          -8           0.233       -12.967
# 2265  2018_1438_1455         6          -5           0.158       -13.131
# 2266  2018_1438_1460         8          -7           0.220      -126.443
# 2267  2018_1438_1462         3          -3           0.091        -6.475
# 2268  2018_1439_1452        -3           1          -0.050        18.688
# 2269  2018_1439_1455        -4           4          -0.125        18.525
# 2270  2018_1439_1460        -2           2          -0.063       -94.787
# 2271  2018_1439_1462        -7           6          -0.192        25.180
# 2272  2018_1452_1455        -1           3          -0.075        -0.164
# 2273  2018_1452_1460         1           1          -0.013      -113.475
# 2274  2018_1452_1462        -4           5          -0.142         6.492
# 2275  2018_1455_1460         2          -2           0.062      -113.312
# 2276  2018_1455_1462        -3           2          -0.067         6.656
# 2277  2018_1460_1462        -5           4          -0.129       119.967
#
#       AbsMeanRankDiff  SeedDiff  coach_expDiff  made_tournamentDiff  \
# 0                  31         5            -11                  -10
# 1                  12        -2             -2                   -1
# 2                  26         2            -13                   -8
# 3                  43         5            -11                   -8
# 4                 -41        -5              0                   -1
# 5                 -17        -4              0                   -1
# 6                  24        -1              1                    0
# 7                  49         7            -12                   -9
# 8                  36         4            -13                   -4
# 9                 -49        -4             -1                    0
# 10                 27         1            -14                   -7
# 11               -113        -6             -2                    0
# 12                -15        -3            -26                   -8
# 13                 51         7            -31                  -32
# 14                 32         3             -4                   -1
# 15                 20         0            -27                   -8
# 16                -69        -6            -17                   -2
# 17                 42         5            -16                  -18
# 18                 33         3            -22                  -14
# 19                -86        -6             -5                   -4
# 20                 46         8            -22                  -19
# 21                 19         0            -17                  -11
# 22                 34         4            -23                  -18
# 23                -93        -6             -4                    0
# 24               -203        -7             -7                   -1
# 25                  9        -2            -11                    0
# 26                -54        -4             -1                    0
# 27                 25         3            -29                   -8
# 28                 44         6            -23                  -11
# 29                 48         6            -20                  -20
# ...               ...       ...            ...                  ...
# 2248               55         2            -11                   -3
# 2249              175        15             -7                   -7
# 2250               81        12            -17                  -14
# 2251               82        12             -5                   -7
# 2252               52         5             -4                   -6
# 2253               68         8            -26                  -23
# 2254               67         9            -13                  -13
# 2255              -44        -1             -6                   -3
# 2256               76        12             -2                   -7
# 2257                1         0             12                    7
# 2258              -29        -7             13                    8
# 2259              -13        -4             -9                   -9
# 2260              -14        -3              4                    1
# 2261             -125       -13             11                   11
# 2262               -5         0             15                    7
# 2263              -30        -7              1                    1
# 2264              -14        -4            -21                  -16
# 2265              -15        -3             -8                   -6
# 2266             -126       -13             -1                    4
# 2267               -6         0              3                    0
# 2268               16         3            -22                  -17
# 2269               15         4             -9                   -7
# 2270              -96        -6             -2                    3
# 2271               24         7              2                   -1
# 2272               -1         1             13                   10
# 2273             -112        -9             20                   20
# 2274                8         4             24                   16
# 2275             -111       -10              7                   10
# 2276                9         3             11                    6
# 2277              120        13              4                   -4
#
#       first_roundDiff           ...            AgstOppOffAvgOppFGA3Diff  \
# 0                 -10           ...                               1.272
# 1                  -1           ...                              -3.018
# 2                  -8           ...                              -1.684
# 3                  -8           ...                              -1.209
# 4                  -1           ...                               2.387
# 5                  -1           ...                               1.703
# 6                   0           ...                               1.698
# 7                  -9           ...                               1.874
# 8                  -4           ...                               0.296
# 9                   0           ...                               1.613
# 10                 -7           ...                              -1.503
# 11                  0           ...                               0.053
# 12                 -8           ...                              -2.266
# 13                -32           ...                              -1.801
# 14                 -1           ...                               2.178
# 15                 -8           ...                              -1.861
# 16                 -2           ...                              -2.933
# 17                -18           ...                               0.102
# 18                -14           ...                               0.561
# 19                 -3           ...                               0.439
# 20                -19           ...                              -1.963
# 21                -11           ...                               1.519
# 22                -18           ...                              -3.303
# 23                  0           ...                              -0.416
# 24                 -1           ...                               1.211
# 25                  0           ...                               1.555
# 26                  0           ...                               1.047
# 27                 -8           ...                               1.289
# 28                -11           ...                               5.311
# 29                -20           ...                              -0.170
# ...               ...           ...                                 ...
# 2248               -3           ...                               1.248
# 2249               -6           ...                              -2.542
# 2250              -14           ...                              -2.346
# 2251               -7           ...                              -1.318
# 2252               -6           ...                              -7.525
# 2253              -23           ...                              -1.837
# 2254              -12           ...                              -4.666
# 2255               -3           ...                              -3.499
# 2256               -6           ...                              -7.289
# 2257                7           ...                               1.028
# 2258                8           ...                              -5.179
# 2259               -9           ...                               0.509
# 2260                2           ...                              -2.320
# 2261               11           ...                              -1.153
# 2262                8           ...                              -4.943
# 2263                1           ...                              -6.207
# 2264              -16           ...                              -0.519
# 2265               -5           ...                              -3.348
# 2266                4           ...                              -2.181
# 2267                1           ...                              -5.971
# 2268              -17           ...                               5.688
# 2269               -6           ...                               2.859
# 2270                3           ...                               4.026
# 2271                0           ...                               0.236
# 2272               11           ...                              -2.829
# 2273               20           ...                              -1.662
# 2274               17           ...                              -5.452
# 2275                9           ...                               1.167
# 2276                6           ...                              -2.623
# 2277               -3           ...                              -3.790
#
#       AgstOppOffAvgOppFTMDiff  AgstOppOffAvgOppFTADiff  \
# 0                       0.740                    2.578
# 1                      -0.222                    0.845
# 2                      -3.040                   -3.028
# 3                      -2.197                   -1.415
# 4                      -2.432                   -2.661
# 5                      -4.511                   -4.479
# 6                      -0.871                    0.286
# 7                       3.245                    5.290
# 8                       2.711                    4.509
# 9                       0.171                    2.390
# 10                      2.758                    4.697
# 11                     -2.218                   -0.734
# 12                      2.409                    3.670
# 13                      3.144                    5.758
# 14                      1.248                    3.443
# 15                     -0.861                    0.114
# 16                     -1.967                   -1.732
# 17                      1.215                    2.805
# 18                     -2.203                   -1.806
# 19                      1.834                    2.489
# 20                      3.645                    5.964
# 21                     -1.332                   -0.070
# 22                      1.022                    1.598
# 23                     -3.855                   -4.607
# 24                     -1.576                   -1.454
# 25                      3.241                    5.297
# 26                      0.257                    0.525
# 27                      1.388                    2.973
# 28                      2.018                    3.792
# 29                      0.379                    2.097
# ...                       ...                      ...
# 2248                   -0.268                    0.416
# 2249                    1.115                    2.732
# 2250                    4.438                    6.184
# 2251                    6.246                    8.522
# 2252                    3.604                    4.425
# 2253                   -1.231                   -2.316
# 2254                    1.574                    2.260
# 2255                    3.018                    3.946
# 2256                    4.401                    6.262
# 2257                    1.808                    2.338
# 2258                   -0.834                   -1.759
# 2259                   -5.669                   -8.500
# 2260                   -2.864                   -3.924
# 2261                   -1.420                   -2.238
# 2262                   -0.037                    0.078
# 2263                   -2.642                   -4.097
# 2264                   -7.477                  -10.838
# 2265                   -4.672                   -6.262
# 2266                   -3.228                   -4.576
# 2267                   -1.845                   -2.260
# 2268                   -4.835                   -6.741
# 2269                   -2.030                   -2.165
# 2270                   -0.586                   -0.479
# 2271                    0.797                    1.837
# 2272                    2.805                    4.576
# 2273                    4.249                    6.262
# 2274                    5.632                    8.578
# 2275                    1.444                    1.686
# 2276                    2.827                    4.002
# 2277                    1.383                    2.316
#
#       AgstOppOffAvgOppORDiff  AgstOppOffAvgOppDRDiff  AgstOppOffAvgOppAstDiff  \
# 0                      2.202                   4.259                   -1.182
# 1                     -0.649                  -1.274                   -4.160
# 2                      0.508                  -0.081                   -2.089
# 3                      1.085                  -0.258                   -1.724
# 4                     -0.527                  -1.479                   -1.384
# 5                      0.443                  -1.245                   -0.711
# 6                      2.741                  -0.153                   -0.126
# 7                      0.815                   2.561                    1.267
# 8                      1.651                   0.366                    0.827
# 9                      1.366                  -0.439                   -0.928
# 10                     1.538                  -1.594                   -1.935
# 11                    -0.011                   0.660                   -2.283
# 12                     2.959                  -0.097                   -1.245
# 13                    -0.675                   3.533                   -2.435
# 14                     0.676                  -1.856                   -0.120
# 15                    -0.301                   0.214                   -1.486
# 16                    -1.263                  -1.039                   -2.504
# 17                     1.454                   0.514                    0.271
# 18                     2.130                   1.396                    0.436
# 19                    -0.520                  -2.884                   -3.657
# 20                    -0.411                   1.011                   -0.900
# 21                     0.829                   0.844                   -0.813
# 22                    -0.890                   2.978                   -1.360
# 23                     1.813                  -2.691                   -2.051
# 24                    -0.967                  -1.898                   -2.720
# 25                     1.469                   2.531                   -1.113
# 26                    -2.576                  -3.782                   -3.869
# 27                     1.174                  -0.087                   -1.286
# 28                     3.227                  -0.380                    1.939
# 29                     0.527                   4.107                   -0.650
# ...                      ...                     ...                      ...
# 2248                   1.467                   2.585                    2.456
# 2249                   2.064                   5.534                    0.897
# 2250                  -1.639                   1.566                   -3.391
# 2251                   0.384                   2.177                    1.754
# 2252                  -1.540                  -0.130                   -3.936
# 2253                  -1.823                  -0.282                   -2.014
# 2254                   0.667                   1.338                   -1.392
# 2255                  -0.720                  -1.227                   -2.151
# 2256                  -0.123                   1.722                   -3.710
# 2257                   2.023                   0.611                    5.145
# 2258                   0.099                  -1.696                   -0.545
# 2259                  -0.184                  -1.848                    1.377
# 2260                   2.306                  -0.228                    1.999
# 2261                   0.919                  -2.793                    1.240
# 2262                   1.516                   0.156                   -0.319
# 2263                  -1.924                  -2.307                   -5.690
# 2264                  -2.207                  -2.459                   -3.768
# 2265                   0.283                  -0.839                   -3.146
# 2266                  -1.104                  -3.404                   -3.905
# 2267                  -0.507                  -0.455                   -5.464
# 2268                  -0.283                  -0.152                    1.922
# 2269                   2.207                   1.468                    2.544
# 2270                   0.820                  -1.097                    1.785
# 2271                   1.417                   1.852                    0.226
# 2272                   2.490                   1.620                    0.622
# 2273                   1.103                  -0.945                   -0.137
# 2274                   1.700                   2.004                   -1.696
# 2275                  -1.387                  -2.565                   -0.759
# 2276                  -0.790                   0.384                   -2.318
# 2277                   0.597                   2.949                   -1.559
#
#       AgstOppOffAvgOppTODiff  AgstOppOffAvgOppStlDiff  \
# 0                      1.893                    0.419
# 1                     -1.445                    1.113
# 2                     -0.904                    1.922
# 3                     -2.032                    0.267
# 4                      0.907                   -0.028
# 5                     -0.544                    1.061
# 6                     -1.138                    1.742
# 7                     -1.552                    1.883
# 8                      0.869                    1.061
# 9                      1.184                    2.261
# 10                     1.598                    0.685
# 11                     0.630                    0.454
# 12                     2.203                    2.351
# 13                     0.660                    0.882
# 14                    -0.502                    2.059
# 15                    -1.380                    1.174
# 16                    -0.289                    1.434
# 17                     0.391                    1.424
# 18                    -0.006                    1.459
# 19                     0.239                    1.829
# 20                     0.037                    1.411
# 21                    -1.244                    1.065
# 22                     1.203                    0.858
# 23                    -1.765                   -0.489
# 24                     1.960                    0.423
# 25                     0.375                    0.292
# 26                    -0.732                   -0.198
# 27                     0.098                    0.794
# 28                     0.093                    2.227
# 29                     3.027                    0.681
# ...                      ...                      ...
# 2248                  -0.296                    0.907
# 2249                   2.559                    0.204
# 2250                   0.612                    2.236
# 2251                   1.053                    2.946
# 2252                   0.790                    1.330
# 2253                  -2.358                    1.287
# 2254                   2.447                    0.611
# 2255                  -0.251                    0.820
# 2256                   2.604                    0.117
# 2257                   0.441                    0.710
# 2258                   0.178                   -0.906
# 2259                  -2.970                   -0.949
# 2260                   1.835                   -1.625
# 2261                  -0.863                   -1.416
# 2262                   1.992                   -2.119
# 2263                  -0.263                   -1.616
# 2264                  -3.411                   -1.659
# 2265                   1.394                   -2.335
# 2266                  -1.304                   -2.126
# 2267                   1.551                   -2.829
# 2268                  -3.148                   -0.043
# 2269                   1.657                   -0.719
# 2270                  -1.041                   -0.510
# 2271                   1.814                   -1.213
# 2272                   4.805                   -0.676
# 2273                   2.107                   -0.467
# 2274                   4.962                   -1.170
# 2275                  -2.698                    0.209
# 2276                   0.157                   -0.494
# 2277                   2.855                   -0.703
#
#       AgstOppOffAvgOppBlkDiff  AgstOppOffAvgOppPFDiff
# 0                       0.678                   0.607
# 1                      -0.310                  -1.174
# 2                      -0.046                   1.035
# 3                       0.141                  -0.246
# 4                      -0.859                  -1.382
# 5                      -1.005                   1.380
# 6                      -0.277                   2.944
# 7                      -0.079                   1.675
# 8                      -0.325                   1.522
# 9                      -0.867                   2.416
# 10                      0.049                   3.691
# 11                     -0.967                   0.461
# 12                      0.200                   3.974
# 13                      0.687                   0.723
# 14                      0.690                   2.425
# 15                      0.512                   0.043
# 16                     -0.878                   3.984
# 17                      0.151                   2.328
# 18                      0.671                   1.349
# 19                      0.000                   3.964
# 20                      0.129                   3.269
# 21                      0.936                   1.707
# 22                      0.040                  -0.012
# 23                     -1.974                  -1.639
# 24                     -0.286                   0.516
# 25                     -0.302                   3.902
# 26                     -0.254                   1.159
# 27                     -0.211                   2.474
# 28                      0.394                   1.611
# 29                      0.835                  -0.321
# ...                       ...                     ...
# 2248                    0.384                  -1.518
# 2249                   -0.162                  -2.666
# 2250                    0.371                  -0.559
# 2251                    1.072                   1.275
# 2252                   -0.200                  -1.538
# 2253                   -0.425                  -2.486
# 2254                   -0.287                  -3.667
# 2255                    0.311                  -3.245
# 2256                   -0.235                  -4.393
# 2257                    0.701                   1.834
# 2258                   -0.571                  -0.979
# 2259                   -0.796                  -1.927
# 2260                   -0.658                  -3.108
# 2261                   -0.060                  -2.686
# 2262                   -0.606                  -3.834
# 2263                   -1.272                  -2.813
# 2264                   -1.497                  -3.761
# 2265                   -1.359                  -4.942
# 2266                   -0.761                  -4.520
# 2267                   -1.307                  -5.668
# 2268                   -0.225                  -0.948
# 2269                   -0.087                  -2.129
# 2270                    0.511                  -1.707
# 2271                   -0.035                  -2.855
# 2272                    0.138                  -1.181
# 2273                    0.736                  -0.759
# 2274                    0.190                  -1.907
# 2275                    0.598                   0.422
# 2276                    0.052                  -0.726
# 2277                   -0.546                  -1.148
#
# [2278 rows x 72 columns]
